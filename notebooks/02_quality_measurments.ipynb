# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')

from process_fragment_miner import evaluation

# %%
evaluation('../data/raw/', '../data/processed/BPIC/')
# Out:
# parsing log, completed traces ::   0%|          | 0/13087 [00:00<?, ?it/s]
# dk
# exporting log, completed traces ::   0%|          | 0/13087 [00:00<?, ?it/s]
# fragment_2: ['O_SENT_BACK', 'O_CANCELLED', 'O_SENT', 'O_CREATED', 'O_SELECTED', 'O_ACCEPTED', 'O_DECLINED']
# exporting log, completed traces ::   0%|          | 0/5015 [00:00<?, ?it/s]
# fragment_0: ['A_APPROVED', 'A_CANCELLED', 'A_ACTIVATED', 'A_ACCEPTED', 'A_REGISTERED', 'A_PARTLYSUBMITTED', 'A_FINALIZED', 'A_SUBMITTED', 'A_PREACCEPTED', 'A_DECLINED']
# exporting log, completed traces ::   0%|          | 0/13087 [00:00<?, ?it/s]
# fragment_1: ['W_Completeren aanvraag', 'W_Nabellen incomplete dossiers', 'W_Afhandelen leads', 'W_Beoordelen fraude', 'W_Wijzigen contractgegevens', 'W_Nabellen offertes', 'W_Valideren aanvraag']
# exporting log, completed traces ::   0%|          | 0/9658 [00:00<?, ?it/s]
# heuristic
# exporting log, completed traces ::   0%|          | 0/13087 [00:00<?, ?it/s]
# ...
